# %% [markdown]
# <a href="https://colab.research.google.com/github/eunzzae/Study_DS/blob/main/29)_%EC%98%81%ED%99%94_%ED%9D%A5%ED%96%89_%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 영화 흥행 예측
# >**목차**
#
# * 문제상황 및 데이터 살펴보기
# * 문제해결 프로세스 정의
# 1) mata 데이터 연결
# 2) 캐릭터, 감독, 성우에 따른 흥행 분석
# 3) ML 활용 영화 흥행 수익 예측

# %%
# ▶ Warnings 제거
import warnings
warnings.filterwarnings('ignore')

# ▶ Google drive mount or 폴더 클릭 후 구글드라이브 연결
from google.colab import drive
drive.mount('/content/drive')

# # ▶ 경로 설정 (※ Colab을 활성화시켰다면 보통 Colab Notebooks 폴더가 자동 생성)
# import os
# os.chdir('/content/drive/MyDrive/Colab Notebooks/part3_lecture_fastcampus/chapter26')
# # '/content/drive/MyDrive/Colab Notebooks/ ← 여기 경로까지는 본인의 경로 입력, part3_lecture_fastcampus/chapter26' ← 변경X
# os.getcwd()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **문제상황 및 데이터 살펴보기**
# ---
# > **시나리오** 🎥 (마케터)
#
# ```
# A사는 이번에 신규 영화를 촬영할 계획을 가지고 있다. 제작비가 크게 들어가는 만큼 그 만큼의 수익이 발생해야하는 상황이기 때문에 최대한 Risk를
# 덜 가져가려고 하고 있다. 이에 과거 상영한 영화의 데이터를 활용하여 감독, 성우에 따라 매출을 극대화하는 캐스팅을 진행하려고 한다.
#
# ```

# %% [markdown]
# ## **문제해결 프로세스 정의**
# ---
# > **문제정의**
#
# ```
#  신규 영화 제작을 위한 캐스팅 Line-up 불분명
# ```
#
# > **기대효과**
#
# ```
# 매출을 극대화 할 수 있는 감독 및 배우 캐스팅 및 영화 흥행
# ```
#
# > **해결방안**
#
# ```
# 과거 영화 데이터 활용 매출 극대화 캐스팅
# Session 1
#  - 각 카테고리별 data 처리 및 merge
# Session 2
#  - 최종 Data set 처리 및 흥행 영화 탐색
# Session 3
#  - ML 알고리즘 활용 영화 흥행 예측
# ```
#
# > **성과측정**
#
# ```
# 캐스팅 후 영화 제작 및 상영 후 매출 모니터링
# ```
#
# > **현업적용**
#
# ```
# 캐스팅 결과 활용
# ```
#
# > **주요 코드 미리 살펴보기**
#
# ```
# session 1 → str.replace(), to_datetime, drop_duplocates
# session 2 → pd.merge(), .notnull()
# session 3 → RandomForestRegressor, LabelEncoder(), mean_absolute_error, r2_score
# ```

# %% [markdown]
# ## Session 1
# ## meta 데이터 연결

# %% [markdown]
# ### Total gross data
# ---

# %%
# movie total gross
import pandas as pd

bath = '/content/drive/MyDrive/[STUDY] 데이터사이언스/데이터분석/data/chapter29_영화 흥행 예측/'
df_movie_gross = pd.read_csv(bath + 'chapter29_disney_movies_total_gross.csv')
print(df_movie_gross.shape)
df_movie_gross.head()
# Out:
# (579, 7)
#    index                      movie_title  release_date      genre  \
# 0      0  Snow White and the Seven Dwarfs  Dec 21, 1937    Musical
# 1      1                        Pinocchio   Feb 9, 1940  Adventure
# 2      2                         Fantasia  Nov 13, 1940    Musical
# 3      3                Song of the South  Nov 12, 1946  Adventure
# 4      4                       Cinderella  Feb 15, 1950      Drama
#
#   MPAA_rating   total_gross inflation_adjusted_gross
# 0           G  $184,925,485         $5,228,953,251\r
# 1           G   $84,300,000         $2,188,229,052\r
# 2           G   $83,320,000         $2,187,090,808\r
# 3           G   $65,000,000         $1,078,510,579\r
# 4           G   $85,000,000           $920,608,730\r

# %%
df_movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     579 non-null    int64
#  1   movie_title               579 non-null    object
#  2   release_date              579 non-null    object
#  3   genre                     562 non-null    object
#  4   MPAA_rating               523 non-null    object
#  5   total_gross               579 non-null    object
#  6   inflation_adjusted_gross  579 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 31.8+ KB

# %%
df_movie_gross.isnull().sum()
# Out:
# index                        0
# movie_title                  0
# release_date                 0
# genre                       17
# MPAA_rating                 56
# total_gross                  0
# inflation_adjusted_gross     0
# dtype: int64

# %%
# 문자열 데이터 전처리 및 null 처리
df_movie_gross['inflation_adjusted_gross'] = df_movie_gross['inflation_adjusted_gross'].str.replace('$', '')
df_movie_gross['inflation_adjusted_gross'] = df_movie_gross['inflation_adjusted_gross'].str.replace(',', '')
df_movie_gross['inflation_adjusted_gross'] = df_movie_gross['inflation_adjusted_gross'].str.replace('\r', '')
df_movie_gross['inflation_adjusted_gross'] = df_movie_gross['inflation_adjusted_gross'].astype(int)

df_movie_gross['total_gross'] = df_movie_gross['total_gross'].str.replace('$', '')
df_movie_gross['total_gross'] = df_movie_gross['total_gross'].str.replace(',', '')
df_movie_gross['total_gross'] = df_movie_gross['total_gross'].str.replace('\r', '')
df_movie_gross['total_gross'] = df_movie_gross['total_gross'].astype(int)

df_movie_gross['genre'].fillna('none', inplace=True)
df_movie_gross['MPAA_rating'].fillna('none', inplace=True)

df_movie_gross = df_movie_gross.drop(['index'], axis=1)
df_movie_gross.head()
# Out:
#                        movie_title  release_date      genre MPAA_rating  \
# 0  Snow White and the Seven Dwarfs  Dec 21, 1937    Musical           G
# 1                        Pinocchio   Feb 9, 1940  Adventure           G
# 2                         Fantasia  Nov 13, 1940    Musical           G
# 3                Song of the South  Nov 12, 1946  Adventure           G
# 4                       Cinderella  Feb 15, 1950      Drama           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808
# 3     65000000                1078510579
# 4     85000000                 920608730

# %%
df_movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    object
#  2   genre                     579 non-null    object
#  3   MPAA_rating               579 non-null    object
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 27.3+ KB

# %%
# 영화별 중복 데이터 존재
df_movie_gross['movie_title'].value_counts()
# Out:
# movie_title
# The Jungle Book                 3
# Freaky Friday                   2
# Cinderella                      2
# Bad Company                     2
# 101 Dalmatians                  2
#                                ..
# Quiz Show                       1
# A Simple Twist of Fate          1
# It's Pat                        1
# Camp Nowhere                    1
# Rogue One: A Star Wars Story    1
# Name: count, Length: 573, dtype: int64

# %%
# 같은 영화명이어도, 장르, 발매년도에 따라 여러 개의 데이터가 존재.
df_movie_gross[df_movie_gross['movie_title']=='The Jungle Book']
# Out:
#          movie_title  release_date      genre MPAA_rating  total_gross  \
# 13   The Jungle Book  Oct 18, 1967    Musical   Not Rated    141843000
# 194  The Jungle Book  Dec 25, 1994  Adventure          PG     44342956
# 567  The Jungle Book  Apr 15, 2016  Adventure          PG    364001123
#
#      inflation_adjusted_gross
# 13                  789612346
# 194                  88930321
# 567                 364001123

# %%
df_movie_gross['release_date'] = pd.to_datetime(df_movie_gross['release_date'])
df_movie_gross.head()
# Out:
#                        movie_title release_date      genre MPAA_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808
# 3     65000000                1078510579
# 4     85000000                 920608730

# %%
# 같은 영화라면 최신에 개봉한 영화만 남기기
df_movie_gross = df_movie_gross.sort_values(by=['movie_title', 'release_date'], ascending=[True, False])
df_movie_gross = df_movie_gross.drop_duplicates('movie_title', keep='first')
df_movie_gross.head()
# Out:
#                       movie_title release_date      genre MPAA_rating  \
# 252                101 Dalmatians   1996-11-27     Comedy           G
# 337                102 Dalmatians   2000-11-22     Comedy           G
# 133    1492: Conquest of Paradise   1992-10-09  Adventure       PG-13
# 5    20,000 Leagues Under the Sea   1954-12-23  Adventure        none
# 375                     25th Hour   2002-12-19      Drama           R
#
#      total_gross  inflation_adjusted_gross
# 252    136189294                 258728898
# 337     66941559                 104055039
# 133      7099531                  14421454
# 5       28200000                 528279994
# 375     13084595                  18325463

# %%
# 중복제거 확인
df_movie_gross['movie_title'].value_counts().head()
# Out:
# movie_title
# 101 Dalmatians       1
# Stakeout             1
# Song of the South    1
# Sorority Boys        1
# Spaced Invaders      1
# Name: count, dtype: int64

# %% [markdown]
# ### voice actor data
# ---

# %%
bath = '/content/drive/MyDrive/[STUDY] 데이터사이언스/데이터분석/data/chapter29_영화 흥행 예측/'
df_voice_actor = pd.read_csv(bath + 'chapter29_disney_voice_actors.csv')
print(df_voice_actor.shape)
df_voice_actor.head()
# Out:
# (935, 4)
#    index       character      voice-actor                        movie
# 0      0    Abby Mallard      Joan Cusack               Chicken Little
# 1      1  Abigail Gabble     Monica Evans               The Aristocats
# 2      2        Abis Mal  Jason Alexander          The Return of Jafar
# 3      3             Abu     Frank Welker                      Aladdin
# 4      4        Achilles              NaN  The Hunchback of Notre Dame

# %%
df_voice_actor.isnull().sum()
# Out:
# index           0
# character       0
# voice-actor    53
# movie           0
# dtype: int64

# %%
# col 재정비
df_voice_actor = df_voice_actor[['movie', 'character','voice-actor']]
df_voice_actor.columns = ['movie_title', 'character', 'voice_actor']
df_voice_actor.head()
# Out:
#                    movie_title       character      voice_actor
# 0               Chicken Little    Abby Mallard      Joan Cusack
# 1               The Aristocats  Abigail Gabble     Monica Evans
# 2          The Return of Jafar        Abis Mal  Jason Alexander
# 3                      Aladdin             Abu     Frank Welker
# 4  The Hunchback of Notre Dame        Achilles              NaN

# %%
# 하나의 영화에 참여한 여러명의 성우가 존재함.
df_voice_actor['movie_title'].value_counts()
# Out:
# movie_title
# DuckTales             31
# Zootopia              22
# Hercules              22
# Wreck-It Ralph        21
# The Little Mermaid    20
#                       ..
# The Plow Boy           1
# Hold That Pose         1
# Grin and Bear It       1
# Saludos Amigos         1
# The Pirate Fairy       1
# Name: count, Length: 139, dtype: int64

# %% [markdown]
# ### director data
# ---

# %%
bath = '/content/drive/MyDrive/[STUDY] 데이터사이언스/데이터분석/data/chapter29_영화 흥행 예측/'
df_director = pd.read_csv(bath + 'chapter29_disney_director.csv')
print(df_director.shape)
df_director.head()
# Out:
# (56, 3)
#    index                             name        director
# 0      0  Snow White and the Seven Dwarfs      David Hand
# 1      1                        Pinocchio  Ben Sharpsteen
# 2      2                         Fantasia    full credits
# 3      3                            Dumbo  Ben Sharpsteen
# 4      4                            Bambi      David Hand

# %%
df_director.isnull().sum()
# Out:
# index       0
# name        0
# director    0
# dtype: int64

# %%
# col 재정비
df_director = df_director[['name','director']]
df_director.columns=['movie_title','director']
df_director.head()
# Out:
#                        movie_title        director
# 0  Snow White and the Seven Dwarfs      David Hand
# 1                        Pinocchio  Ben Sharpsteen
# 2                         Fantasia    full credits
# 3                            Dumbo  Ben Sharpsteen
# 4                            Bambi      David Hand

# %%
# 중복없음
df_director['movie_title'].value_counts().head()
# Out:
# movie_title
# Snow White and the Seven Dwarfs    1
# Pinocchio                          1
# Aladdin                            1
# The Lion King                      1
# Pocahontas                         1
# Name: count, dtype: int64

# %% [markdown]
# ### song data
# ---

# %%
bath = '/content/drive/MyDrive/[STUDY] 데이터사이언스/데이터분석/data/chapter29_영화 흥행 예측/'
df_song = pd.read_csv(bath + 'chapter29_disney_characters.csv')
print(df_song.shape)
df_song.head()
# Out:
# (56, 6)
#    index                        movie_title       release_date        hero  \
# 0      0  \nSnow White and the Seven Dwarfs  December 21, 1937  Snow White
# 1      1                        \nPinocchio   February 7, 1940   Pinocchio
# 2      2                         \nFantasia  November 13, 1940         NaN
# 3      3                              Dumbo   October 23, 1941       Dumbo
# 4      4                            \nBambi    August 13, 1942       Bambi
#
#       villian                          song
# 0  Evil Queen  Some Day My Prince Will Come
# 1   Stromboli     When You Wish upon a Star
# 2   Chernabog                           NaN
# 3  Ringmaster                     Baby Mine
# 4      Hunter                Love Is a Song

# %%
df_song.isnull().sum()
# Out:
# index            0
# movie_title      0
# release_date     0
# hero             4
# villian         10
# song             9
# dtype: int64

# %%
# 문자열 데이터 처리
import re
df_song['movie_title'] = df_song['movie_title'].str.replace('\n','')
df_song.fillna('none', inplace=True)
df_song.drop(['index'], axis=1, inplace=True)
df_song.head()
# Out:
#                        movie_title       release_date        hero     villian  \
# 0  Snow White and the Seven Dwarfs  December 21, 1937  Snow White  Evil Queen
# 1                        Pinocchio   February 7, 1940   Pinocchio   Stromboli
# 2                         Fantasia  November 13, 1940        none   Chernabog
# 3                            Dumbo   October 23, 1941       Dumbo  Ringmaster
# 4                            Bambi    August 13, 1942       Bambi      Hunter
#
#                            song
# 0  Some Day My Prince Will Come
# 1     When You Wish upon a Star
# 2                          none
# 3                     Baby Mine
# 4                Love Is a Song

# %%
df_song.isnull().sum()
# Out:
# movie_title     0
# release_date    0
# hero            0
# villian         0
# song            0
# dtype: int64

# %%
# 중복없음
df_song['movie_title'].value_counts().head()
# Out:
# movie_title
# Snow White and the Seven Dwarfs    1
# Pinocchio                          1
# Aladdin                            1
# The Lion King                      1
# Pocahontas                         1
# Name: count, dtype: int64

# %% [markdown]
# ## Session 2
# ## 캐릭터, 감독, 성우에 따른 흥행 분석

# %% [markdown]
# ### Data 연결
# ---
# * df_movie_gross : 영화 수익 (Base data) - 중복 X
# * df_voice_actor : 영화 캐릭터 별 성우 - 중복 O
# * df_director : 영화 감독 - 중복 X
# * df_song : 영화 OST 및 히어로/빌런 - 중복 X

# %%
# 중복없는 데이터 우선 merge
df_merge = pd.merge(df_movie_gross, df_director, how='left', on='movie_title')
df_merge.head()
# Out:
#                     movie_title release_date      genre MPAA_rating  \
# 0                101 Dalmatians   1996-11-27     Comedy           G
# 1                102 Dalmatians   2000-11-22     Comedy           G
# 2    1492: Conquest of Paradise   1992-10-09  Adventure       PG-13
# 3  20,000 Leagues Under the Sea   1954-12-23  Adventure        none
# 4                     25th Hour   2002-12-19      Drama           R
#
#    total_gross  inflation_adjusted_gross             director
# 0    136189294                 258728898  Wolfgang Reitherman
# 1     66941559                 104055039                  NaN
# 2      7099531                  14421454                  NaN
# 3     28200000                 528279994                  NaN
# 4     13084595                  18325463                  NaN

# %%
df_song.head()
# Out:
#                        movie_title       release_date        hero     villian  \
# 0  Snow White and the Seven Dwarfs  December 21, 1937  Snow White  Evil Queen
# 1                        Pinocchio   February 7, 1940   Pinocchio   Stromboli
# 2                         Fantasia  November 13, 1940        none   Chernabog
# 3                            Dumbo   October 23, 1941       Dumbo  Ringmaster
# 4                            Bambi    August 13, 1942       Bambi      Hunter
#
#                            song
# 0  Some Day My Prince Will Come
# 1     When You Wish upon a Star
# 2                          none
# 3                     Baby Mine
# 4                Love Is a Song

# %%
# df_song의 release_date 중복 col이기 때문에 제거 후 merge
df_song = df_song.drop(['release_date'], axis=1)
df_merge = pd.merge(df_merge, df_song, how='left', on='movie_title')
df_merge.head()
# Out:
#                     movie_title release_date      genre MPAA_rating  \
# 0                101 Dalmatians   1996-11-27     Comedy           G
# 1                102 Dalmatians   2000-11-22     Comedy           G
# 2    1492: Conquest of Paradise   1992-10-09  Adventure       PG-13
# 3  20,000 Leagues Under the Sea   1954-12-23  Adventure        none
# 4                     25th Hour   2002-12-19      Drama           R
#
#    total_gross  inflation_adjusted_gross             director hero villian  \
# 0    136189294                 258728898  Wolfgang Reitherman  NaN     NaN
# 1     66941559                 104055039                  NaN  NaN     NaN
# 2      7099531                  14421454                  NaN  NaN     NaN
# 3     28200000                 528279994                  NaN  NaN     NaN
# 4     13084595                  18325463                  NaN  NaN     NaN
#
#   song
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# 중복없음
df_merge['movie_title'].value_counts()
# Out:
# movie_title
# 101 Dalmatians          1
# Stakeout                1
# Song of the South       1
# Sorority Boys           1
# Spaced Invaders         1
#                        ..
# Green Card              1
# Good Morning Vietnam    1
# Gone in 60 Seconds      1
# Gone Fishin'            1
# crazy/beautiful         1
# Name: count, Length: 573, dtype: int64

# %%
# 영화 흥행 수익 데이터 대비 감독과 음악(OST)이 현저히 적음
df_movie_gross.shape,df_director.shape, df_song.shape
# Out:
# ((573, 6), (56, 2), (56, 4))

# %%
df_merge.isnull().sum()
# Out:
# movie_title                   0
# release_date                  0
# genre                         0
# MPAA_rating                   0
# total_gross                   0
# inflation_adjusted_gross      0
# director                    528
# hero                        529
# villian                     529
# song                        529
# dtype: int64

# %% [markdown]
# ### 성우 데이터 처리
# ---

# %%
df_merge.head()
# Out:
#                     movie_title release_date      genre MPAA_rating  \
# 0                101 Dalmatians   1996-11-27     Comedy           G
# 1                102 Dalmatians   2000-11-22     Comedy           G
# 2    1492: Conquest of Paradise   1992-10-09  Adventure       PG-13
# 3  20,000 Leagues Under the Sea   1954-12-23  Adventure        none
# 4                     25th Hour   2002-12-19      Drama           R
#
#    total_gross  inflation_adjusted_gross             director hero villian  \
# 0    136189294                 258728898  Wolfgang Reitherman  NaN     NaN
# 1     66941559                 104055039                  NaN  NaN     NaN
# 2      7099531                  14421454                  NaN  NaN     NaN
# 3     28200000                 528279994                  NaN  NaN     NaN
# 4     13084595                  18325463                  NaN  NaN     NaN
#
#   song
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# voice actor의 경우 중복 데이터가 많기 때문에 hero에 성우와 villian의 성우만 조인
hero_list = list(df_merge[df_merge['hero'].notnull()]['hero'])
Villian_list = list(df_merge[df_merge['villian'].notnull()]['villian'])

print(hero_list)
print(Villian_list)
# Out:
# ['Aladdin', 'Alice', 'Milo Thatch', 'Belle', 'Hiro Hamada', 'Bolt', 'Kenai', 'Ace Cluck', 'Cinderella', 'Aladar', 'none', 'Elsa', 'Hercules', 'Maggie', 'Lady and Tramp', 'Lilo and Stitch', 'Lewis', 'Moana', 'Mulan', 'Oliver', 'Pinocchio', 'Pocahontas', 'Aurora', 'Snow White', 'Rapunzel', 'Tarzan', 'Thomas and Duchess', 'Taran', 'Kuzco', 'Tod and Copper', 'Basil', 'Quasimodo', 'Mowgli', 'Simba', 'Ariel', 'Winnie the Pooh', 'Tiana', 'Bernard and Miss Bianca', 'Bernard and Miss Bianca', 'Arthur', 'Jim Hawkins', 'Winnie the Pooh', 'Ralph', 'Judy Hopps']
# ['Jafar', 'Queen of Hearts', 'Commander Rourke', 'Gaston', 'Professor Callaghan', 'Dr. Calico', 'Denahi', 'Foxy Loxy', 'Lady Tremaine', 'Kron', 'Chernabog', 'Prince Hans', 'Hades', 'Alameda Slim', 'Si and Am', 'none', 'Doris', 'none', 'Shan Yu', 'Sykes', 'Stromboli', 'Governor Ratcliffe', 'Maleficent', 'Evil Queen', 'Mother Gothel', 'Clayton', 'Edgar Balthazar', 'Horned King', 'Yzma', 'Amos Slade', 'Professor Ratigan', 'Claude Frollo', 'Kaa and Shere Khan', 'Scar', 'Ursula', 'none', 'Dr. Facilier', 'Madame Medusa', 'Percival C. McLeach', 'Madam Mim', 'John Silver', 'none', 'Turbo', 'none']

# %%
# 주인공 성우도 2명이 진행한 이력이 있음.
df_voice_actor[df_voice_actor['character'].isin(hero_list)]['movie_title'].value_counts().head()
# Out:
# movie_title
# Tarzan                       2
# The Lion King                2
# Dinosaur                     1
# Home on the Range            1
# The Princess and the Frog    1
# Name: count, dtype: int64

# %%
# 중복이라면 두명의 배우를 모두 넣기 위해 이름을 구분지음.
df_hero = pd.DataFrame(df_voice_actor[df_voice_actor['character'].isin(hero_list)].groupby(['movie_title', 'character']).agg(lambda x: "; ".join(x)))
df_hero = df_hero.reset_index()
df_hero = df_hero[['character', 'voice_actor']]
df_hero.columns = ['character', 'hero_actor']
df_hero.head(10)
# Out:
#      character                   hero_actor
# 0      Aladdin     Scott Weinger; Brad Kane
# 1        Alice             Kathryn Beaumont
# 2  Milo Thatch               Michael J. Fox
# 3        Belle                 Paige O'Hara
# 4         Bolt                John Travolta
# 5        Kenai              Joaquin Phoenix
# 6   Cinderella                  Ilene Woods
# 7       Aladar                D. B. Sweeney
# 8         Elsa                 Idina Menzel
# 9     Hercules  Tate Donovan; Joshua Keaton

# %%
# 빌런, 중복이 없음.
df_voice_actor[df_voice_actor['character'].isin(Villian_list)]['movie_title'].value_counts().head()
# Out:
# movie_title
# Home on the Range        1
# The Fox and the Hound    1
# The Little Mermaid       1
# Oliver & Company         1
# Pinocchio                1
# Name: count, dtype: int64

# %%
# 빌런 Data
df_villian = pd.DataFrame(df_voice_actor[df_voice_actor['character'].isin(Villian_list)])
df_villian = df_villian[['character', 'voice_actor']]
df_villian.columns = ['character', 'villian_actor']
df_villian.head(5)
# Out:
#         character   villian_actor
# 14   Alameda Slim     Randy Quaid
# 22     Amos Slade  Jack Albertson
# 167     Chernabog    Corey Burton
# 184       Clayton   Brian Blessed
# 222        Denahi     Jason Raize

# %%
# 기존 Data
df_merge.head()
# Out:
#                     movie_title release_date      genre MPAA_rating  \
# 0                101 Dalmatians   1996-11-27     Comedy           G
# 1                102 Dalmatians   2000-11-22     Comedy           G
# 2    1492: Conquest of Paradise   1992-10-09  Adventure       PG-13
# 3  20,000 Leagues Under the Sea   1954-12-23  Adventure        none
# 4                     25th Hour   2002-12-19      Drama           R
#
#    total_gross  inflation_adjusted_gross             director hero villian  \
# 0    136189294                 258728898  Wolfgang Reitherman  NaN     NaN
# 1     66941559                 104055039                  NaN  NaN     NaN
# 2      7099531                  14421454                  NaN  NaN     NaN
# 3     28200000                 528279994                  NaN  NaN     NaN
# 4     13084595                  18325463                  NaN  NaN     NaN
#
#   song
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# 성우 데이터 merge

# Hero
df_merge = pd.merge(df_merge, df_hero, how='left', left_on = 'hero', right_on='character')

# Villian
df_merge = pd.merge(df_merge, df_villian, how='left', left_on='villian', right_on='character')

df_merge.head()
# Out:
#                     movie_title release_date      genre MPAA_rating  \
# 0                101 Dalmatians   1996-11-27     Comedy           G
# 1                102 Dalmatians   2000-11-22     Comedy           G
# 2    1492: Conquest of Paradise   1992-10-09  Adventure       PG-13
# 3  20,000 Leagues Under the Sea   1954-12-23  Adventure        none
# 4                     25th Hour   2002-12-19      Drama           R
#
#    total_gross  inflation_adjusted_gross             director hero villian  \
# 0    136189294                 258728898  Wolfgang Reitherman  NaN     NaN
# 1     66941559                 104055039                  NaN  NaN     NaN
# 2      7099531                  14421454                  NaN  NaN     NaN
# 3     28200000                 528279994                  NaN  NaN     NaN
# 4     13084595                  18325463                  NaN  NaN     NaN
#
#   song character_x hero_actor character_y villian_actor
# 0  NaN         NaN        NaN         NaN           NaN
# 1  NaN         NaN        NaN         NaN           NaN
# 2  NaN         NaN        NaN         NaN           NaN
# 3  NaN         NaN        NaN         NaN           NaN
# 4  NaN         NaN        NaN         NaN           NaN

# %%
# 중복 col 삭제
df_merge = df_merge.drop(['character_x', 'character_y'], axis=1)
df_merge.head()
# Out:
#                     movie_title release_date      genre MPAA_rating  \
# 0                101 Dalmatians   1996-11-27     Comedy           G
# 1                102 Dalmatians   2000-11-22     Comedy           G
# 2    1492: Conquest of Paradise   1992-10-09  Adventure       PG-13
# 3  20,000 Leagues Under the Sea   1954-12-23  Adventure        none
# 4                     25th Hour   2002-12-19      Drama           R
#
#    total_gross  inflation_adjusted_gross             director hero villian  \
# 0    136189294                 258728898  Wolfgang Reitherman  NaN     NaN
# 1     66941559                 104055039                  NaN  NaN     NaN
# 2      7099531                  14421454                  NaN  NaN     NaN
# 3     28200000                 528279994                  NaN  NaN     NaN
# 4     13084595                  18325463                  NaN  NaN     NaN
#
#   song hero_actor villian_actor
# 0  NaN        NaN           NaN
# 1  NaN        NaN           NaN
# 2  NaN        NaN           NaN
# 3  NaN        NaN           NaN
# 4  NaN        NaN           NaN

# %% [markdown]
# > **데이터 살펴보기**
#
# * 영화 관련 데이터
# * 데이터 명세 ⬇
#
# |movie_title|release_date_x|genre|MPAA_rating|total_gross|inflation_adjusted_gross||
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# |영화제목|발매일|장르|영화평점|총수익|인플레이션 반영 수익|
# |hero|villian|song|director|hero_actor|villian_actor|
# |주인공|빌런|음악|감독|hero 성우|villian 성우|

# %%
df_merge.isnull().sum()
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573 entries, 0 to 572
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               573 non-null    object
#  1   release_date              573 non-null    datetime64[ns]
#  2   genre                     573 non-null    object
#  3   MPAA_rating               573 non-null    object
#  4   total_gross               573 non-null    int64
#  5   inflation_adjusted_gross  573 non-null    int64
#  6   director                  45 non-null     object
#  7   hero                      44 non-null     object
#  8   villian                   44 non-null     object
#  9   song                      44 non-null     object
#  10  hero_actor                32 non-null     object
#  11  villian_actor             28 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 53.8+ KB

# %%
# 최종 Data set, 나라도 Nan이 있으면 해석할 수 없기때문에 전체 삭제
df_merge = df_merge.dropna()
df_merge.head()
# Out:
#              movie_title release_date      genre MPAA_rating  total_gross  \
# 25               Aladdin   1992-11-11     Comedy           G    217350219
# 53  Beauty and the Beast   1991-11-13    Musical           G    218951625
# 71                  Bolt   2008-11-21     Comedy          PG    114053759
# 81          Brother Bear   2003-10-24  Adventure           G     85336277
# 97            Cinderella   2015-03-13      Drama          PG    201151353
#
#     inflation_adjusted_gross         director        hero        villian  \
# 25                 441969178     Ron Clements     Aladdin          Jafar
# 53                 363017667   Gary Trousdale       Belle         Gaston
# 71                 133702498   Chris Williams        Bolt     Dr. Calico
# 81                 119218333    Robert Walker       Kenai         Denahi
# 97                 201151353  Wilfred Jackson  Cinderella  Lady Tremaine
#
#                     song                hero_actor  \
# 25     A Whole New World  Scott Weinger; Brad Kane
# 53          Be Our Guest              Paige O'Hara
# 71  I Thought I Lost You             John Travolta
# 81  Look Through My Eyes           Joaquin Phoenix
# 97   Bibbidi-Bobbidi-Boo               Ilene Woods
#
#                         villian_actor
# 25                   Jonathan Freeman
# 53                      Richard White
# 71                   Malcolm McDowell
# 81                        Jason Raize
# 97  Eleanor Audley; Susanne Blakeslee

# %% [markdown]
# ### 흥행 EDA
# ---

# %%
df_merge.shape
# Out:
# (22, 12)

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 25 to 532
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               22 non-null     object
#  1   release_date              22 non-null     datetime64[ns]
#  2   genre                     22 non-null     object
#  3   MPAA_rating               22 non-null     object
#  4   total_gross               22 non-null     int64
#  5   inflation_adjusted_gross  22 non-null     int64
#  6   director                  22 non-null     object
#  7   hero                      22 non-null     object
#  8   villian                   22 non-null     object
#  9   song                      22 non-null     object
#  10  hero_actor                22 non-null     object
#  11  villian_actor             22 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 2.2+ KB

# %%
# 장르별 손익
pd.DataFrame(df_merge.groupby('genre')['inflation_adjusted_gross'].mean().sort_values(ascending=False))
# Out:
#            inflation_adjusted_gross
# genre
# Musical                3.630177e+08
# Adventure              3.440411e+08
# Comedy                 2.145273e+08
# Drama                  1.113286e+08

# %%
# 감독별 손익
pd.options.display.float_format = '{:.2f}'.format
pd.DataFrame(df_merge.groupby('director')['inflation_adjusted_gross'].mean().sort_values(ascending=False)).reset_index()
# Out:
#                director  inflation_adjusted_gross
# 0        Ben Sharpsteen             2188229052.00
# 1          Roger Allers              761640898.00
# 2        Gary Trousdale              363017667.00
# 3            Chris Buck              349448714.00
# 4            Barry Cook              216807832.00
# 5          Ralph Zondag              215438985.00
# 6          Nathan Greno              214388548.00
# 7          Ron Clements              203846040.80
# 8       Wilfred Jackson              201151353.00
# 9   Wolfgang Reitherman              153870834.00
# 10          Mark Dindal              136789252.00
# 11       Chris Williams              133702498.00
# 12  Stephen J. Anderson              119860589.00
# 13        Robert Walker              119218333.00
# 14      George Scribner              102254492.00
# 15            Will Finn               67910166.00
# 16       Clyde Geronimi               21505832.00

# %%
# 성우별 손익(Hero, Villian)
pd.DataFrame(df_merge.groupby(['hero_actor', 'villian_actor'])['inflation_adjusted_gross'].mean().sort_values(ascending=False))
# Out:
#                                                                              inflation_adjusted_gross
# hero_actor                                villian_actor
# Dickie Jones                              Charles Judels                                2188229052.00
# Jonathan Taylor Thomas; Matthew Broderick Jeremy Irons                                   761640898.00
# Scott Weinger; Brad Kane                  Jonathan Freeman                               441969178.00
# Idina Menzel                              Santino Fontana                                414997174.00
# Paige O'Hara                              Richard White                                  363017667.00
# Tony Goldwyn; Alex D. Linz                Brian Blessed                                  283900254.00
# Jodi Benson                               Pat Carroll                                    223726012.00
# Ming-Na Wen; Lea Salonga                  Miguel Ferrer                                  216807832.00
# D. B. Sweeney                             Samuel E. Wright                               215438985.00
# Mandy Moore                               Donna Murphy                                   214388548.00
# Ilene Woods                               Eleanor Audley; Susanne Blakeslee              201151353.00
# Tate Donovan; Joshua Keaton               James Woods                                    182029412.00
# David Lander                              Martha Wentworth                               153870834.00
# David Spade                               Eartha Kitt                                    136789252.00
# John Travolta                             Malcolm McDowell                               133702498.00
# Jordan Fry                                Ethan Sandler                                  119860589.00
# Joaquin Phoenix                           Jason Raize                                    119218333.00
# Anika Noni Rose                           Keith David                                    116316457.00
# Joey Lawrence                             Robert Loggia                                  102254492.00
# Roseanne Barr                             Randy Quaid                                     67910166.00
# Joseph Gordon-Levitt                      Brian Murray                                    55189145.00
# Mary Costa                                Eleanor Audley                                  21505832.00

# %% [markdown]
# ## Session 3
# ## ML 활용 영화 흥행 수익 예측

# %% [markdown]
# ### 모델링을 위한 데이터 준비
# ---

# %%
df_merge.head()
# Out:
#              movie_title release_date      genre MPAA_rating  total_gross  \
# 25               Aladdin   1992-11-11     Comedy           G    217350219
# 53  Beauty and the Beast   1991-11-13    Musical           G    218951625
# 71                  Bolt   2008-11-21     Comedy          PG    114053759
# 81          Brother Bear   2003-10-24  Adventure           G     85336277
# 97            Cinderella   2015-03-13      Drama          PG    201151353
#
#     inflation_adjusted_gross         director        hero        villian  \
# 25                 441969178     Ron Clements     Aladdin          Jafar
# 53                 363017667   Gary Trousdale       Belle         Gaston
# 71                 133702498   Chris Williams        Bolt     Dr. Calico
# 81                 119218333    Robert Walker       Kenai         Denahi
# 97                 201151353  Wilfred Jackson  Cinderella  Lady Tremaine
#
#                     song                hero_actor  \
# 25     A Whole New World  Scott Weinger; Brad Kane
# 53          Be Our Guest              Paige O'Hara
# 71  I Thought I Lost You             John Travolta
# 81  Look Through My Eyes           Joaquin Phoenix
# 97   Bibbidi-Bobbidi-Boo               Ilene Woods
#
#                         villian_actor
# 25                   Jonathan Freeman
# 53                      Richard White
# 71                   Malcolm McDowell
# 81                        Jason Raize
# 97  Eleanor Audley; Susanne Blakeslee

# %%
# 사전 필요없는 col 제거
df_merge = df_merge.drop(['movie_title', 'release_date','MPAA_rating', 'total_gross','song'], axis=1)
df_merge.head()
# Out:
#         genre  inflation_adjusted_gross         director        hero  \
# 25     Comedy                 441969178     Ron Clements     Aladdin
# 53    Musical                 363017667   Gary Trousdale       Belle
# 71     Comedy                 133702498   Chris Williams        Bolt
# 81  Adventure                 119218333    Robert Walker       Kenai
# 97      Drama                 201151353  Wilfred Jackson  Cinderella
#
#           villian                hero_actor                      villian_actor
# 25          Jafar  Scott Weinger; Brad Kane                   Jonathan Freeman
# 53         Gaston              Paige O'Hara                      Richard White
# 71     Dr. Calico             John Travolta                   Malcolm McDowell
# 81         Denahi           Joaquin Phoenix                        Jason Raize
# 97  Lady Tremaine               Ilene Woods  Eleanor Audley; Susanne Blakeslee

# %%
# 기존 코드를 활용하기 위해 copy()
df = df_merge.copy()

# %%
# numeric, categorical value 나누기
numeric_list=[]
categorical_list=[]

for i in df.columns :
  if df[i].dtypes == object :
    categorical_list.append(i)
  else :
    numeric_list.append(i)

print("categorical_list :", categorical_list)
print("numeric_list :", numeric_list)
# Out:
# categorical_list : ['genre', 'director', 'hero', 'villian', 'hero_actor', 'villian_actor']
# numeric_list : ['inflation_adjusted_gross']

# %%
# 모델링을 학습하기 위한 Fearue(X)와 Y데이터를 구분하는 단계
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

X=df.drop(['inflation_adjusted_gross'], axis=1)
Y=df['inflation_adjusted_gross']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

print(x_train.shape)
print(y_train.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (15, 6)
# (15,)
# (7, 6)
# (7,)

# %%
from sklearn.preprocessing import LabelEncoder

for col in categorical_list :
  print(col)
  le = LabelEncoder()
  le.fit(list(x_train[col].values) + list(x_test[col].values))
  x_train[col] = le.transform(x_train[col])
  x_test[col] = le.transform(x_test[col])
# Out:
# genre
# director
# hero
# villian
# hero_actor
# villian_actor

# %%
x_test[categorical_list]
# Out:
#      genre  director  hero  villian  hero_actor  villian_actor
# 71       1         3     6        4          10             13
# 404      0         2    20        1          21              0
# 470      0        12     2       20           8             16
# 512      0        16     3       12           2             14
# 53       3         5     5        6          17             18
# 281      0         0    15       17          16             15
# 260      0        13    13        3          12              7

# %% [markdown]
# ### 모델 학습 및 평가
# ---

# %%
rfr = RandomForestRegressor(n_estimators=200, max_depth=3)
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=3, n_estimators=200)

# %%
# 예측
# 예측은 학습에 사용된 Data와 Test Data 모두 예측하고 평가함(※ 과적합 여부 판별)
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
y_pred_train = rfr.predict(x_train)
y_pred_test = rfr.predict(x_test)


mae_train = mean_absolute_error(y_train, y_pred_train)
print('mae_train(mae): ', mae_train)
r2_train = r2_score(y_train, y_pred_train)
print('r2_score(r2): ', r2_train)
print('')
mae_test = mean_absolute_error(y_test, y_pred_test)
print('mae_test(mae): ', mae_test)
r2_test = r2_score(y_test, y_pred_test)
print('r2_score(r2): ', r2_test)
# Out:
# mae_train(mae):  171630858.25997573
# r2_score(r2):  0.8063363666187663
#
# mae_test(mae):  341471778.8310679
# r2_score(r2):  -35.12190877267933

# %%
pd.options.display.float_format = '{:.5f}'.format
result = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred_test})
result['diff'] = result['Real Values'] - result['Predicted Values']
result.head(5)
# Out:
#      Real Values  Predicted Values             diff
# 71     133702498   413656530.92933 -279954032.92933
# 404    283900254   908344276.29592 -624444022.29592
# 470    223726012   349378177.08220 -125652165.08220
# 512    153870834   253143677.81546  -99272843.81546
# 53     363017667   183396586.64105  179621080.35895

# %% [markdown]
# ### 중요 변수 파악
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#plt.rc('font', family='NanumBarunGothic')
# %matplotlib inline
plt.style.use(['dark_background'])

ftr_importances_values = rfr.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index = x_train.columns)
ftr_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature Importances')
sns.barplot(x=ftr_top20, y=ftr_top20.index)
plt.show()

# %% [markdown]
# ### 모델 저장
# ---

# %%
import pickle
# 모델 저장
saved_model = pickle.dumps(rfr)

# 모델 Read
rfr_from_pickle = pickle.loads(saved_model)
